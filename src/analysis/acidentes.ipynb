# %% [markdown]
# ### Importando as bibliotecas necessárias para iniciar a leitura dos arquivos

# %%
import pandas as pd

# %% [markdown]
# ### Importando arquivos do período de 2011 a 2021

# %%
df_2011 = pd.read_csv("../../databases/acidentes2011.csv", encoding="latin")
df_2012 = pd.read_csv("../../databases/acidentes2012.csv", encoding="latin")
df_2013 = pd.read_csv("../../databases/acidentes2013.csv", encoding="latin")
df_2014 = pd.read_csv("../../databases/acidentes2014.csv", encoding="latin")
df_2015 = pd.read_csv("../../databases/acidentes2015.csv", encoding="latin")
df_2016 = pd.read_csv("../../databases/acidentes2016.csv", encoding="latin", sep=";")
df_2017 = pd.read_csv("../../databases/acidentes2017.csv", encoding="latin", sep=";")
df_2018 = pd.read_csv("../../databases/acidentes2018.csv", encoding="latin", sep=";")
df_2019 = pd.read_csv("../../databases/acidentes2019.csv", encoding="latin", sep=";")
df_2020 = pd.read_csv("../../databases/acidentes2020.csv", encoding="latin", sep=";")
df_2021 = pd.read_csv("../../databases/acidentes2021.csv", encoding="latin", sep=";")
# Out:
# /var/folders/z1/3syxl8gd5ks431s8c9n9mrs00000gn/T/ipykernel_9239/1180877235.py:2: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2012 = pd.read_csv("../../databases/acidentes2012.csv", encoding="latin")

# %% [markdown]
# ### Verificando as informações dos dados presentes em cada arquivo

# %%
df_2011.info()
df_2012.info()
df_2013.info()
df_2014.info()
df_2015.info()
df_2016.info()
df_2017.info()
df_2018.info()
df_2019.info()
df_2020.info()
df_2021.info()

# %% [markdown]
# ### Unificando arquivos do período de 2011 a 2021 em um único arquivo

# %%
df_2011_2021 = pd.concat([
    df_2011,
    df_2012,
    df_2013,
    df_2014,
    df_2015,
    df_2016,
    df_2017,
    df_2018,
    df_2019,
    df_2020,
    df_2021
],
    ignore_index=True
)
df_2011_2021.info()
df_2011_2021
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2818892 entries, 0 to 2818891
# Data columns (total 37 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   id                      float64
#  1   pesid                   float64
#  2   data_inversa            object
#  3   dia_semana              object
#  4   horario                 object
#  5   uf                      object
#  6   br                      object
#  7   km                      object
#  8   municipio               object
#  9   causa_acidente          object
#  10  tipo_acidente           object
#  11  classificacao_acidente  object
#  12  fase_dia                object
#  13  sentido_via             object
#  14  condicao_metereologica  object
#  15  tipo_pista              object
#  16  tracado_via             object
#  17  uso_solo                object
#  18  id_veiculo              object
#  19  tipo_veiculo            object
#  20  marca                   object
#  21  ano_fabricacao_veiculo  object
#  22  tipo_envolvido          object
#  23  estado_fisico           object
#  24  idade                   float64
#  25  sexo                    object
#  26  nacionalidade           object
#  27  naturalidade            object
#  28  ilesos                  float64
#  29  feridos_leves           float64
#  30  feridos_graves          float64
#  31  mortos                  float64
#  32  latitude                object
#  33  longitude               object
#  34  regional                object
#  35  delegacia               object
#  36  uop                     object
# dtypes: float64(7), object(30)
# memory usage: 795.7+ MB
#                id      pesid data_inversa     dia_semana   horario  uf     br  \
# 0         26946.0  2715647.0   16/04/2011        Sábado   22:20:00  SP    153
# 1        674607.0  2033386.0   29/08/2011        Segunda  16:10:00  RJ    101
# 2        674607.0  2033390.0   29/08/2011        Segunda  16:10:00  RJ    101
# 3        830363.0  2525787.0   01/01/2011        Sábado   01:00:00  RJ    116
# 4        830383.0  2533410.0   01/01/2011        Sábado   00:15:00  CE    116
# ...           ...        ...          ...            ...       ...  ..    ...
# 2818887  374024.0   833912.0   2021-06-28  segunda-feira  10:50:00  PR  277.0
# 2818888  374224.0   834254.0   2021-06-13        domingo  02:50:00  SP  116.0
# 2818889  374239.0   834287.0   2021-06-02   quarta-feira  08:45:00  RN  101.0
# 2818890  374239.0   834286.0   2021-06-02   quarta-feira  08:45:00  RN  101.0
# 2818891  374253.0   834310.0   2021-01-01    sexta-feira  17:40:00  RN  101.0
#
#             km              municipio  \
# 0         59.9  SAO JOSE DO RIO PRETO
# 1        488.0         ANGRA DOS REIS
# 2        488.0         ANGRA DOS REIS
# 3        214.0                  PIRAI
# 4         69.6             CHOROZINHO
# ...        ...                    ...
# 2818887    576               CASCAVEL
# 2818888  102,7        PINDAMONHANGABA
# 2818889     85                  NATAL
# 2818890     85                  NATAL
# 2818891   78,4                  NATAL
#
#                                    causa_acidente  ...   naturalidade ilesos  \
# 0                              Ingestão de álcool  ...          Uchoa    NaN
# 1                                Falta de atenção  ...  Não Informado    NaN
# 2                                Falta de atenção  ...  Não Informado    NaN
# 3                                          Outras  ...  Volta Redonda    NaN
# 4                     Desobediência à sinalização  ...  Não Informado    NaN
# ...                                           ...  ...            ...    ...
# 2818887                   Velocidade Incompatível  ...            NaN    1.0
# 2818888  Reação tardia ou ineficiente do condutor  ...            NaN    0.0
# 2818889                   Velocidade Incompatível  ...            NaN    0.0
# 2818890                   Velocidade Incompatível  ...            NaN    1.0
# 2818891               Manobra de mudança de faixa  ...            NaN    0.0
#
#         feridos_leves feridos_graves mortos      latitude     longitude  \
# 0                 NaN            NaN    NaN           NaN           NaN
# 1                 NaN            NaN    NaN           NaN           NaN
# 2                 NaN            NaN    NaN           NaN           NaN
# 3                 NaN            NaN    NaN           NaN           NaN
# 4                 NaN            NaN    NaN           NaN           NaN
# ...               ...            ...    ...           ...           ...
# 2818887           0.0            0.0    0.0  -24,98692731  -53,33030208
# 2818888           1.0            0.0    0.0  -22,99497994  -45,48951403
# 2818889           0.0            1.0    0.0     -5,777664     -35,24937
# 2818890           0.0            0.0    0.0     -5,777664     -35,24937
# 2818891           0.0            1.0    0.0   -5,74071896  -35,29021064
#
#         regional delegacia    uop
# 0            NaN       NaN    NaN
# 1            NaN       NaN    NaN
# 2            NaN       NaN    NaN
# 3            NaN       NaN    NaN
# 4            NaN       NaN    NaN
# ...          ...       ...    ...
# 2818887    SR-PR     UOP01  DEL04
# 2818888    SR-SP     UOP01  DEL08
# 2818889    SR-RN     UOP01  DEL02
# 2818890    SR-RN     UOP01  DEL02
# 2818891    SR-RN     UOP01  DEL02
#
# [2818892 rows x 37 columns]

# %% [markdown]
# ### Removendo colunas que não considero necessárias para a análise, provenientes dos arquivos à partir do ano de 2017 (latitude, longitude, regional, delegacia, uop)

# %%
df_2011_2021 = df_2011_2021.drop(columns=[
    "latitude",
    "longitude",
    "regional",
    "delegacia",
    "uop"
])
df_2011_2021.head()
# Out:
#          id      pesid data_inversa dia_semana   horario  uf   br     km  \
# 0   26946.0  2715647.0   16/04/2011    Sábado   22:20:00  SP  153   59.9
# 1  674607.0  2033386.0   29/08/2011    Segunda  16:10:00  RJ  101  488.0
# 2  674607.0  2033390.0   29/08/2011    Segunda  16:10:00  RJ  101  488.0
# 3  830363.0  2525787.0   01/01/2011    Sábado   01:00:00  RJ  116  214.0
# 4  830383.0  2533410.0   01/01/2011    Sábado   00:15:00  CE  116   69.6
#
#                municipio               causa_acidente  ... tipo_envolvido  \
# 0  SAO JOSE DO RIO PRETO           Ingestão de álcool  ...       Condutor
# 1         ANGRA DOS REIS             Falta de atenção  ...       Condutor
# 2         ANGRA DOS REIS             Falta de atenção  ...       Condutor
# 3                  PIRAI                       Outras  ...       Condutor
# 4             CHOROZINHO  Desobediência à sinalização  ...       Condutor
#
#   estado_fisico idade       sexo nacionalidade   naturalidade ilesos  \
# 0  Ileso         40.0  Masculino        Brasil          Uchoa    NaN
# 1  Ileso         52.0  Masculino        Brasil  Não Informado    NaN
# 2  Ileso         40.0  Masculino        Brasil  Não Informado    NaN
# 3  Ileso         35.0  Masculino        Brasil  Volta Redonda    NaN
# 4  Ileso         46.0  Masculino        Brasil  Não Informado    NaN
#
#   feridos_leves feridos_graves mortos
# 0           NaN            NaN    NaN
# 1           NaN            NaN    NaN
# 2           NaN            NaN    NaN
# 3           NaN            NaN    NaN
# 4           NaN            NaN    NaN
#
# [5 rows x 32 columns]
